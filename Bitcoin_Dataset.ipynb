# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/Bitcoin_dataset_updated.csv')

# %%
df.iloc[1095:, :]
# Out:
#             Date  BTC price [USD]  n-transactions  fee [USD]  \
# 1095  2017-01-01           964.84        180502.0       0.39
# 1096  2017-01-02           997.36        290951.0        NaN
# 1097  2017-01-03          1013.42        301664.0        NaN
# 1098  2017-01-04          1037.83        328642.0       0.42
# 1099  2017-01-05          1109.16        288501.0        NaN
# ...          ...              ...             ...        ...
# 2305  2020-04-25          7507.08        280805.0       0.75
# 2306  2020-04-26          7549.52        252833.0       0.62
# 2307  2020-04-27          7699.27        311217.0       0.69
# 2308  2020-04-28          7790.66        323475.0       0.66
# 2309  2020-04-29          7765.33        331401.0       1.30
#
#       btc search trends  Gold price[USD]  SP500 close index  \
# 1095                  6              NaN                NaN
# 1096                  6          1151.05                NaN
# ...

# %%
ls = df.iloc[1095:, [0,1,5]]

# %%
plt.plot(ls.iloc[:, 0], ls.iloc[:, 1])

# %%
plt.plot(df.iloc[1095:,0], df.iloc[1095:,1])

# %%
plt.plot(df.iloc[1095:,0], df.iloc[1095:,2])

# %%
plt.plot(df.iloc[1095:,0], df.iloc[1095:,5])

# %%
plt.plot(df.iloc[1095:,0], df.iloc[1095:,7])
